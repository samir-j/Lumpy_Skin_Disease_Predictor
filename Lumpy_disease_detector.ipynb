# %%
import cv2 as cv
import os
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
lumpy_skin_dir_path = r'/content/drive/MyDrive/Lumpy_skin_image_dataset/Lumpy Skin'
normal_skin_dir_path = r'/content/drive/MyDrive/Lumpy_skin_image_dataset/Normal Skin'

# %%
images = []

def load_image_labels(dir_path, label):
    for filename in os.listdir(dir_path):
        if filename.endswith((".png",".jpg", ".jpeg")):
            image_path = os.path.join(dir_path,filename)
            images.append({'image_path' : image_path, 'label' : label})

    return pd.DataFrame(images)

lumpy_df = load_image_labels(lumpy_skin_dir_path, 'Lumpy')
healthy_df = load_image_labels(normal_skin_dir_path, "Healthy")
combined_df = pd.concat([lumpy_df, healthy_df]).reset_index(drop=True)

print(combined_df)
# Out:
#                                              image_path    label
# 0     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# 1     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# 2     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# 3     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# 4     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# ...                                                 ...      ...
# 1343  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1344  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1345  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1346  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1347  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
#
# [1348 rows x 2 columns]

# %%
image = cv.imread(lumpy_df.image_path[0])
image.shape
# Out:
# (256, 256, 3)

# %%
combined_df.tail(5)
# Out:
#                                              image_path    label
# 1343  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1344  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1345  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1346  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1347  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy

# %%
combined_df.shape
# Out:
# (1348, 2)

# %%
lumpy_df.shape
# Out:
# (324, 2)

# %%
healthy_df.shape
# Out:
# (1024, 2)

# %%
def load_and_preprocess_image(image_path):
    image = cv.imread(image_path)
    if image is not None:
        image_resized = cv.resize(image, (224, 224))
        return image_resized
    else:
        return None

combined_df['preprocessed_image'] = combined_df['image_path'].apply(load_and_preprocess_image)

print(combined_df)
# Out:
#                                              image_path    label  \
# 0     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# 1     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# 2     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# 3     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# 4     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# ...                                                 ...      ...
# 1343  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1344  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1345  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1346  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1347  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
#
#                                      preprocessed_image
# 0     [[[74, 135, 78], [118, 177, 129], [132, 188, 1...
# 1     [[[11, 11, 11], [11, 11, 11], [11, 11, 11], [1...
# 2     [[[32, 15, 30], [181, 145, 137], [239, 191, 16...
# 3     [[[154, 173, 170], [124, 142, 140], [144, 158,...
# 4     [[[182, 199, 220], [182, 199, 220], [182, 199,...
# ...                                                 ...
# 1343  [[[243, 206, 154], [245, 202, 152], [251, 202,...
# 1344  [[[173, 207, 207], [190, 222, 220], [217, 238,...
# 1345  [[[226, 222, 211], [236, 232, 221], [228, 224,...
# 1346  [[[107, 175, 145], [101, 172, 143], [101, 174,...
# 1347  [[[237, 247, 230], [243, 251, 239], [237, 243,...
#
# [1348 rows x 3 columns]

# %%
combined_df
# Out:
#                                              image_path    label  \
# 0     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# 1     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# 2     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# 3     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# 4     /content/drive/MyDrive/Lumpy_skin_image_datase...    Lumpy
# ...                                                 ...      ...
# 1343  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1344  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1345  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1346  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
# 1347  /content/drive/MyDrive/Lumpy_skin_image_datase...  Healthy
#
#                                      preprocessed_image
# 0     [[[74, 135, 78], [118, 177, 129], [132, 188, 1...
# 1     [[[11, 11, 11], [11, 11, 11], [11, 11, 11], [1...
# 2     [[[32, 15, 30], [181, 145, 137], [239, 191, 16...
# 3     [[[154, 173, 170], [124, 142, 140], [144, 158,...
# 4     [[[182, 199, 220], [182, 199, 220], [182, 199,...
# ...                                                 ...
# 1343  [[[243, 206, 154], [245, 202, 152], [251, 202,...
# 1344  [[[173, 207, 207], [190, 222, 220], [217, 238,...
# 1345  [[[226, 222, 211], [236, 232, 221], [228, 224,...
# 1346  [[[107, 175, 145], [101, 172, 143], [101, 174,...
# 1347  [[[237, 247, 230], [243, 251, 239], [237, 243,...
#
# [1348 rows x 3 columns]

# %%
images = np.array(combined_df['preprocessed_image'].tolist())
labels = combined_df['label'].map({'Lumpy': 1, 'Healthy': 0}).values

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.applications import InceptionV3,ResNet50, VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D
import numpy as np


X_train, X_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow(X_train, y_train, batch_size=32)

val_generator = val_datagen.flow(X_val, y_val, batch_size=32)

# %%
def build_simple_cnn(input_shape=(224, 224, 3)):

    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
def build_vgg16(input_shape=(224, 224, 3)):
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
def build_resnet50(input_shape=(224, 224, 3)):
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
def build_inceptionv3(input_shape=(224, 224, 3)):
    base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
models = {
    "Simple CNN": build_simple_cnn(),
    "ResNet50": build_resnet50(),
    "VGG16": build_vgg16(),
    "InceptionV3": build_inceptionv3()
}

results = {}

for model_name, model in models.items():
    print(f"Training {model_name}...")
    checkpoint = ModelCheckpoint(f"{model_name}_best_model.keras", monitor="val_accuracy", save_best_only=True)
    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=30,
        callbacks=[checkpoint]
        # workers=4,
        # use_multiprocessing=True
    )

    val_loss, val_accuracy = model.evaluate(val_generator)
    results[model_name] = {"Loss": val_loss, "Accuracy": val_accuracy}


    y_pred = model.predict(val_generator)
    y_pred_classes = (y_pred > 0.5).astype("int32")
    cm = confusion_matrix(y_val, y_pred_classes)

    print(f"{model_name} Confusion Matrix:")
    print(cm)
    print(f"{model_name} Accuracy: {val_accuracy}")
    # checkpoint = ModelCheckpoint(f"{model_name}___best_model.keras", monitor="val_accuracy", save_best_only=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Training Simple CNN...
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 19s 324ms/step - accuracy: 0.4856 - loss: 0.7132 - val_accuracy: 0.7185 - val_loss: 0.5279
# Epoch 2/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.7032 - loss: 0.5743 - val_accuracy: 0.8185 - val_loss: 0.4810
# Epoch 3/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.8156 - loss: 0.4712 - val_accuracy: 0.8259 - val_loss: 0.4160
# Epoch 4/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8361 - loss: 0.3926 - val_accuracy: 0.8074 - val_loss: 0.3783
# Epoch 5/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8169 - loss: 0.3601 - val_accuracy: 0.8148 - val_loss: 0.3750
# Epoch 6/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9009 - loss: 0.2526 - val_accuracy: 0.8444 - val_loss: 0.4034
# Epoch 7/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.8983 - loss: 0.2653 - val_accuracy: 0.8148 - val_loss: 0.4934
# Epoch 8/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9185 - loss: 0.2077 - val_accuracy: 0.8556 - val_loss: 0.4606
# Epoch 9/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9364 - loss: 0.1435 - val_accuracy: 0.8815 - val_loss: 0.3675
# Epoch 10/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9752 - loss: 0.0767 - val_accuracy: 0.9148 - val_loss: 0.3253
# Epoch 11/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9825 - loss: 0.0698 - val_accuracy: 0.8852 - val_loss: 0.4543
# Epoch 12/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9714 - loss: 0.1316 - val_accuracy: 0.9074 - val_loss: 0.3181
# Epoch 13/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9665 - loss: 0.0991 - val_accuracy: 0.9111 - val_loss: 0.2842
# Epoch 14/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9893 - loss: 0.0516 - val_accuracy: 0.9185 - val_loss: 0.4403
# Epoch 15/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.9846 - loss: 0.1035 - val_accuracy: 0.8889 - val_loss: 0.4595
# Epoch 16/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9912 - loss: 0.0461 - val_accuracy: 0.9222 - val_loss: 0.3250
# Epoch 17/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9901 - loss: 0.0425 - val_accuracy: 0.9185 - val_loss: 0.3997
# Epoch 18/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9938 - loss: 0.0408 - val_accuracy: 0.9111 - val_loss: 0.4196
# Epoch 19/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9945 - loss: 0.0187 - val_accuracy: 0.9259 - val_loss: 0.2688
# Epoch 20/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9912 - loss: 0.0258 - val_accuracy: 0.9111 - val_loss: 0.3368
# Epoch 21/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9942 - loss: 0.0242 - val_accuracy: 0.9111 - val_loss: 0.4486
# Epoch 22/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9970 - loss: 0.0272 - val_accuracy: 0.9037 - val_loss: 0.4824
# Epoch 23/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9958 - loss: 0.0180 - val_accuracy: 0.9148 - val_loss: 0.4348
# Epoch 24/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9901 - loss: 0.0248 - val_accuracy: 0.9148 - val_loss: 0.4357
# Epoch 25/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9974 - loss: 0.0124 - val_accuracy: 0.9000 - val_loss: 0.4773
# Epoch 26/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9968 - loss: 0.0168 - val_accuracy: 0.9000 - val_loss: 0.4950
# Epoch 27/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9974 - loss: 0.0144 - val_accuracy: 0.9148 - val_loss: 0.3688
# Epoch 28/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9981 - loss: 0.0076 - val_accuracy: 0.9074 - val_loss: 0.4417
# Epoch 29/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9918 - loss: 0.0241 - val_accuracy: 0.9111 - val_loss: 0.4631
# Epoch 30/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9960 - loss: 0.0156 - val_accuracy: 0.9185 - val_loss: 0.3833
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9267 - loss: 0.4053
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step
# Simple CNN Confusion Matrix:
# [[66 72]
#  [62 70]]
# Simple CNN Accuracy: 0.9185185432434082
# Training ResNet50...
# Epoch 1/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 27s 449ms/step - accuracy: 0.5615 - loss: 0.6810 - val_accuracy: 0.6593 - val_loss: 0.6131
# Epoch 2/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.6890 - loss: 0.5911 - val_accuracy: 0.6630 - val_loss: 0.5935
# Epoch 3/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - accuracy: 0.6790 - loss: 0.5932 - val_accuracy: 0.7111 - val_loss: 0.5835
# Epoch 4/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - accuracy: 0.7116 - loss: 0.5639 - val_accuracy: 0.7148 - val_loss: 0.5634
# Epoch 5/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - accuracy: 0.7517 - loss: 0.5276 - val_accuracy: 0.7259 - val_loss: 0.5398
# Epoch 6/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.7324 - loss: 0.5368 - val_accuracy: 0.6963 - val_loss: 0.5619
# Epoch 7/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - accuracy: 0.7460 - loss: 0.5152 - val_accuracy: 0.7407 - val_loss: 0.5200
# Epoch 8/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 0.7388 - loss: 0.5374 - val_accuracy: 0.7593 - val_loss: 0.5251
# Epoch 9/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.7611 - loss: 0.5015 - val_accuracy: 0.7481 - val_loss: 0.5052
# Epoch 10/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.7397 - loss: 0.4982 - val_accuracy: 0.7667 - val_loss: 0.4941
# Epoch 11/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.7687 - loss: 0.4891 - val_accuracy: 0.7000 - val_loss: 0.5626
# Epoch 12/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7437 - loss: 0.4886 - val_accuracy: 0.7741 - val_loss: 0.4834
# Epoch 13/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.7596 - loss: 0.4927 - val_accuracy: 0.7111 - val_loss: 0.5670
# Epoch 14/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.7623 - loss: 0.4964 - val_accuracy: 0.7667 - val_loss: 0.4892
# Epoch 15/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.7870 - loss: 0.4774 - val_accuracy: 0.7926 - val_loss: 0.4724
# Epoch 16/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.7968 - loss: 0.4561 - val_accuracy: 0.8111 - val_loss: 0.4697
# Epoch 17/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.8016 - loss: 0.4493 - val_accuracy: 0.8000 - val_loss: 0.4597
# Epoch 18/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.8019 - loss: 0.4553 - val_accuracy: 0.7926 - val_loss: 0.4626
# Epoch 19/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.7844 - loss: 0.4587 - val_accuracy: 0.7185 - val_loss: 0.5523
# Epoch 20/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.7826 - loss: 0.4544 - val_accuracy: 0.8074 - val_loss: 0.4580
# Epoch 21/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 105ms/step - accuracy: 0.7839 - loss: 0.4333 - val_accuracy: 0.8074 - val_loss: 0.4484
# Epoch 22/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.7791 - loss: 0.4732 - val_accuracy: 0.8037 - val_loss: 0.4519
# Epoch 23/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 0.8105 - loss: 0.4229 - val_accuracy: 0.6852 - val_loss: 0.5764
# Epoch 24/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.7977 - loss: 0.4397 - val_accuracy: 0.7593 - val_loss: 0.4702
# Epoch 25/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.7999 - loss: 0.4231 - val_accuracy: 0.8037 - val_loss: 0.4471
# Epoch 26/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.8363 - loss: 0.4000 - val_accuracy: 0.8074 - val_loss: 0.4412
# Epoch 27/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.8083 - loss: 0.4190 - val_accuracy: 0.8074 - val_loss: 0.4389
# Epoch 28/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.8303 - loss: 0.3917 - val_accuracy: 0.8000 - val_loss: 0.4398
# Epoch 29/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.8268 - loss: 0.4162 - val_accuracy: 0.8000 - val_loss: 0.4433
# Epoch 30/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.8250 - loss: 0.4051 - val_accuracy: 0.8000 - val_loss: 0.4369
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.8262 - loss: 0.4154
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 462ms/step
# ResNet50 Confusion Matrix:
# [[64 74]
#  [64 68]]
# ResNet50 Accuracy: 0.800000011920929
# Training VGG16...
# Epoch 1/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 39s 767ms/step - accuracy: 0.5379 - loss: 0.7175 - val_accuracy: 0.8259 - val_loss: 0.5143
# Epoch 2/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.8409 - loss: 0.4734 - val_accuracy: 0.8074 - val_loss: 0.4312
# Epoch 3/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - accuracy: 0.8469 - loss: 0.4014 - val_accuracy: 0.8333 - val_loss: 0.3919
# Epoch 4/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 166ms/step - accuracy: 0.8535 - loss: 0.3793 - val_accuracy: 0.8556 - val_loss: 0.3684
# Epoch 5/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.8512 - loss: 0.3750 - val_accuracy: 0.8370 - val_loss: 0.3640
# Epoch 6/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - accuracy: 0.8487 - loss: 0.3540 - val_accuracy: 0.8296 - val_loss: 0.3764
# Epoch 7/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 166ms/step - accuracy: 0.8717 - loss: 0.3232 - val_accuracy: 0.8593 - val_loss: 0.3320
# Epoch 8/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 164ms/step - accuracy: 0.8848 - loss: 0.2957 - val_accuracy: 0.8593 - val_loss: 0.3369
# Epoch 9/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 166ms/step - accuracy: 0.8795 - loss: 0.3086 - val_accuracy: 0.8741 - val_loss: 0.3181
# Epoch 10/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 159ms/step - accuracy: 0.8680 - loss: 0.3103 - val_accuracy: 0.8667 - val_loss: 0.3110
# Epoch 11/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8808 - loss: 0.3076 - val_accuracy: 0.8556 - val_loss: 0.3333
# Epoch 12/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - accuracy: 0.8827 - loss: 0.2904 - val_accuracy: 0.8889 - val_loss: 0.2971
# Epoch 13/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.8929 - loss: 0.2766 - val_accuracy: 0.8852 - val_loss: 0.3073
# Epoch 14/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - accuracy: 0.9137 - loss: 0.2450 - val_accuracy: 0.8963 - val_loss: 0.2917
# Epoch 15/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - accuracy: 0.8947 - loss: 0.2598 - val_accuracy: 0.8741 - val_loss: 0.2981
# Epoch 16/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.9181 - loss: 0.2384 - val_accuracy: 0.8852 - val_loss: 0.2875
# Epoch 17/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step - accuracy: 0.9130 - loss: 0.2305 - val_accuracy: 0.9000 - val_loss: 0.2837
# Epoch 18/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.9226 - loss: 0.2188 - val_accuracy: 0.8926 - val_loss: 0.2804
# Epoch 19/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 156ms/step - accuracy: 0.9202 - loss: 0.2390 - val_accuracy: 0.8778 - val_loss: 0.2975
# Epoch 20/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 165ms/step - accuracy: 0.9153 - loss: 0.2153 - val_accuracy: 0.8963 - val_loss: 0.2749
# Epoch 21/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step - accuracy: 0.9203 - loss: 0.2077 - val_accuracy: 0.9037 - val_loss: 0.2693
# Epoch 22/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - accuracy: 0.9414 - loss: 0.1875 - val_accuracy: 0.9074 - val_loss: 0.2718
# Epoch 23/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.9244 - loss: 0.2087 - val_accuracy: 0.8741 - val_loss: 0.2939
# Epoch 24/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 159ms/step - accuracy: 0.9269 - loss: 0.2036 - val_accuracy: 0.9000 - val_loss: 0.2739
# Epoch 25/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9362 - loss: 0.1852 - val_accuracy: 0.9000 - val_loss: 0.2781
# Epoch 26/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9231 - loss: 0.2113 - val_accuracy: 0.9037 - val_loss: 0.2620
# Epoch 27/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 159ms/step - accuracy: 0.9469 - loss: 0.1614 - val_accuracy: 0.9000 - val_loss: 0.2638
# Epoch 28/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9382 - loss: 0.1697 - val_accuracy: 0.9037 - val_loss: 0.2621
# Epoch 29/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - accuracy: 0.9420 - loss: 0.1639 - val_accuracy: 0.8926 - val_loss: 0.2644
# Epoch 30/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - accuracy: 0.9389 - loss: 0.1706 - val_accuracy: 0.8519 - val_loss: 0.3370
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.8327 - loss: 0.3253
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step
# VGG16 Confusion Matrix:
# [[53 85]
#  [53 79]]
# VGG16 Accuracy: 0.8518518805503845
# Training InceptionV3...
# Epoch 1/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 37s 649ms/step - accuracy: 0.5493 - loss: 0.9554 - val_accuracy: 0.8630 - val_loss: 0.3805
# Epoch 2/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.8566 - loss: 0.3478 - val_accuracy: 0.8556 - val_loss: 0.3333
# Epoch 3/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - accuracy: 0.8795 - loss: 0.2831 - val_accuracy: 0.8815 - val_loss: 0.2948
# Epoch 4/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.9196 - loss: 0.2365 - val_accuracy: 0.9000 - val_loss: 0.2784
# Epoch 5/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.9368 - loss: 0.2054 - val_accuracy: 0.8852 - val_loss: 0.2991
# Epoch 6/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.9591 - loss: 0.1626 - val_accuracy: 0.8926 - val_loss: 0.3037
# Epoch 7/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.9545 - loss: 0.1550 - val_accuracy: 0.8926 - val_loss: 0.2900
# Epoch 8/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9630 - loss: 0.1194 - val_accuracy: 0.9111 - val_loss: 0.2709
# Epoch 9/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - accuracy: 0.9822 - loss: 0.0885 - val_accuracy: 0.9222 - val_loss: 0.2726
# Epoch 10/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.9841 - loss: 0.0760 - val_accuracy: 0.8926 - val_loss: 0.3473
# Epoch 11/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.9859 - loss: 0.0671 - val_accuracy: 0.9259 - val_loss: 0.2538
# Epoch 12/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.9896 - loss: 0.0558 - val_accuracy: 0.8852 - val_loss: 0.3934
# Epoch 13/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.9889 - loss: 0.0612 - val_accuracy: 0.9407 - val_loss: 0.2505
# Epoch 14/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.9977 - loss: 0.0327 - val_accuracy: 0.8926 - val_loss: 0.3817
# Epoch 15/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.9935 - loss: 0.0387 - val_accuracy: 0.9296 - val_loss: 0.2941
# Epoch 16/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9974 - loss: 0.0256 - val_accuracy: 0.9333 - val_loss: 0.3113
# Epoch 17/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.9957 - loss: 0.0229 - val_accuracy: 0.9407 - val_loss: 0.2785
# Epoch 18/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.9942 - loss: 0.0281 - val_accuracy: 0.9222 - val_loss: 0.3586
# Epoch 19/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.9982 - loss: 0.0192 - val_accuracy: 0.9222 - val_loss: 0.3657
# Epoch 20/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.9926 - loss: 0.0323 - val_accuracy: 0.9259 - val_loss: 0.3358
# Epoch 21/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9961 - loss: 0.0192 - val_accuracy: 0.9407 - val_loss: 0.3099
# Epoch 22/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9981 - loss: 0.0150 - val_accuracy: 0.9407 - val_loss: 0.3220
# Epoch 23/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.9969 - loss: 0.0142 - val_accuracy: 0.9370 - val_loss: 0.3270
# Epoch 24/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.9988 - loss: 0.0152 - val_accuracy: 0.9407 - val_loss: 0.3196
# Epoch 25/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9975 - loss: 0.0169 - val_accuracy: 0.9407 - val_loss: 0.3233
# Epoch 26/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.9990 - loss: 0.0112 - val_accuracy: 0.9370 - val_loss: 0.3510
# Epoch 27/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.9944 - loss: 0.0168 - val_accuracy: 0.9148 - val_loss: 0.4827
# Epoch 28/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.9974 - loss: 0.0139 - val_accuracy: 0.9222 - val_loss: 0.3881
# Epoch 29/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.9957 - loss: 0.0151 - val_accuracy: 0.9370 - val_loss: 0.3492
# Epoch 30/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 0.9948 - loss: 0.0206 - val_accuracy: 0.9037 - val_loss: 0.5136
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9114 - loss: 0.4361
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 657ms/step
# InceptionV3 Confusion Matrix:
# [[58 80]
#  [64 68]]
# InceptionV3 Accuracy: 0.9037036895751953

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)            │ (None, 5, 5, 2048)          │      21,802,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_2           │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 22,589,989 (86.17 MB)
#  Trainable params: 262,401 (1.00 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)
#  Optimizer params: 524,804 (2.00 MB)
